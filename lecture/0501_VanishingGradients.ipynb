# %% [markdown]
# ### Weight Initialization & The Vanishing Gradient Problem
#
# + gradient vanishing problem, 미분값 최대 0.25,
# + 이것을 $0.25^7 = 0.000061035 $

# %%
# %load_ext tensorboard

# %%
import tensorflow as tf
from tensorflow.keras.datasets import mnist
import numpy as np
import matplotlib.pyplot as plt
import datetime

tf.keras.datasets.mnist

# %%
#1
(x_train, y_train), (x_test, y_test) = mnist.load_data()

#2:normalize images
x_train = x_train.astype('float32')
x_test  = x_test.astype('float32')
x_train /= 255.0 # [0, 1]
x_test  /= 255.0

#3: one-hot encoding
y_train = tf.keras.utils.to_categorical(y_train) # (60000, 10)
y_test = tf.keras.utils.to_categorical(y_test)   # (10000, 10)

# %%
#4: build a model
init = tf.keras.initializers.Constant(0.1)
##init = tf.keras.initializers.RandomUniform(-0.5, 0.5) # 'random_uniform’

# %%
# kernel_initializer='glorot_uniform',

model = tf.keras.Sequential()
model.add(tf.keras.layers.Flatten(input_shape=(28, 28)))
model.add(tf.keras.layers.Dense(units=5, activation='sigmoid', kernel_initializer=init))
model.add(tf.keras.layers.Dense(units=5, activation='sigmoid', kernel_initializer=init))
model.add(tf.keras.layers.Dense(units=5, activation='sigmoid', kernel_initializer=init))
model.add(tf.keras.layers.Dense(units=5, activation='sigmoid', kernel_initializer=init))
model.add(tf.keras.layers.Dense(units=5, activation='sigmoid', kernel_initializer=init))
model.add(tf.keras.layers.Dense(units=10,activation='softmax', kernel_initializer=init))
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  flatten (Flatten)           (None, 784)               0
#
#  dense (Dense)               (None, 5)                 3925
#
#  dense_1 (Dense)             (None, 5)                 30
#
#  dense_2 (Dense)             (None, 5)                 30
#
#  dense_3 (Dense)             (None, 5)                 30
#
#  dense_4 (Dense)             (None, 5)                 30
#
#  dense_5 (Dense)             (None, 10)                60
#
# =================================================================
# Total params: 4,105
# Trainable params: 4,105
# Non-trainable params: 0
# _________________________________________________________________

# %%
opt = tf.keras.optimizers.RMSprop(learning_rate=0.01)
model.compile(optimizer=opt, loss='categorical_crossentropy', metrics=['accuracy'])

# %%
log_dir = "./logs/3201/"
file_writer = tf.summary.create_file_writer(log_dir + "/gradient")
file_writer.set_as_default()

# %%
#6:  calculate averages and histograms of gradients in layers
class GradientCallback(tf.keras.callbacks.Callback):
  def __init__(self, freq=10):
  ##        super(GradientCallback, self).__init__()
      self.freq = freq

  def on_epoch_end(self, epoch, logs):
      if epoch%self.freq != 0:
          return

      with tf.GradientTape() as tape:
          y_pred = model(x_train)  # tensor, logits
          loss   = tf.keras.losses.binary_crossentropy(y_train, y_pred)
      grads = tape.gradient(loss, model.trainable_weights)

      for n in range(1, len(model.layers)):
          i2 = (n-1)*2 # weights
          i1 = i2 + 1  # biases

          bias_avg   = tf.reduce_mean(tf.abs(grads[i1]))
          weight_avg = tf.reduce_mean(tf.abs(grads[i2]))

          tf.summary.scalar("layer_%d/avg/bias"%n, data=bias_avg, step=epoch)
          tf.summary.scalar("layer_%d/avg/weight"%n, data=weight_avg, step=epoch)

          tf.summary.histogram("layer_%d/hist/bias"%n, data=grads[i1], step=epoch)
          tf.summary.histogram("layer_%d/hist/weight"%n, data=grads[i2], step=epoch)

          tf.print('epoch: {}, layer-{}, i1: {}, i2: {}'.format(epoch, n, i1, i2))

      feature_extractor = tf.keras.Model(
          inputs=model.inputs,
          outputs=[layer.output for layer in model.layers],
      )
      features = feature_extractor(x_train)
      for i, f in enumerate(features):
        print('type_i: {}, type_f: {}'.format(type(i), type(f)))
        output_avg = tf.reduce_mean(tf.abs(f))
        tf.summary.scalar("layer_%d/avg/output"%i, data=output_avg, step=epoch)
        tf.summary.histogram("layer_%d/hist/output"%i, data=f, step=epoch)

  def on_train_end(self, logs):
      tf.summary.flush()

callback1 = GradientCallback() # freq = 10
callback2 = tf.keras.callbacks.TensorBoard(log_dir=log_dir, histogram_freq= 10) #profile_batch=0

# %%
#7: train and evaluate the model
ret = model.fit(x_train, y_train, epochs=101, batch_size=200, validation_split=0.2,
                 verbose=1, callbacks=[callback1, callback2])
# Out:
# Epoch 1/101
#   1/240 [..............................] - ETA: 15s - loss: 2.2955 - accuracy: 0.1500WARNING:tensorflow:Callback method `on_train_batch_end` is slow compared to the batch time (batch time: 0.0031s vs `on_train_batch_end` time: 0.0105s). Check your callbacks.
# 232/240 [============================>.] - ETA: 0s - loss: 2.3018 - accuracy: 0.1133epoch: 0, layer-1, i1: 1, i2: 0
# epoch: 0, layer-2, i1: 3, i2: 2
# epoch: 0, layer-3, i1: 5, i2: 4
# epoch: 0, layer-4, i1: 7, i2: 6
# epoch: 0, layer-5, i1: 9, i2: 8
# epoch: 0, layer-6, i1: 11, i2: 10
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# 240/240 [==============================] - 87s 362ms/step - loss: 2.3018 - accuracy: 0.1134 - val_loss: 2.3027 - val_accuracy: 0.1060
# Epoch 2/101
# 240/240 [==============================] - 7s 23ms/step - loss: 2.3017 - accuracy: 0.1140 - val_loss: 2.3033 - val_accuracy: 0.1060
# Epoch 3/101
# 240/240 [==============================] - 2s 10ms/step - loss: 2.3017 - accuracy: 0.1140 - val_loss: 2.3023 - val_accuracy: 0.1060
# Epoch 4/101
# 240/240 [==============================] - 2s 7ms/step - loss: 2.3017 - accuracy: 0.1140 - val_loss: 2.3022 - val_accuracy: 0.1060
# Epoch 5/101
# 240/240 [==============================] - 1s 6ms/step - loss: 2.3016 - accuracy: 0.1132 - val_loss: 2.3024 - val_accuracy: 0.1060
# Epoch 6/101
# 240/240 [==============================] - 1s 5ms/step - loss: 2.3015 - accuracy: 0.1139 - val_loss: 2.3021 - val_accuracy: 0.1081
# Epoch 7/101
# 240/240 [==============================] - 1s 6ms/step - loss: 2.3015 - accuracy: 0.1133 - val_loss: 2.3022 - val_accuracy: 0.1060
# Epoch 8/101
# 240/240 [==============================] - 1s 6ms/step - loss: 2.3015 - accuracy: 0.1136 - val_loss: 2.3022 - val_accuracy: 0.1060
# Epoch 9/101
# 240/240 [==============================] - 1s 4ms/step - loss: 2.3016 - accuracy: 0.1140 - val_loss: 2.3023 - val_accuracy: 0.1060
# Epoch 10/101
# 240/240 [==============================] - 1s 4ms/step - loss: 2.3016 - accuracy: 0.1140 - val_loss: 2.3031 - val_accuracy: 0.1060
# Epoch 11/101
# 227/240 [===========================>..] - ETA: 0s - loss: 2.3015 - accuracy: 0.1135epoch: 10, layer-1, i1: 1, i2: 0
# epoch: 10, layer-2, i1: 3, i2: 2
# epoch: 10, layer-3, i1: 5, i2: 4
# epoch: 10, layer-4, i1: 7, i2: 6
# epoch: 10, layer-5, i1: 9, i2: 8
# epoch: 10, layer-6, i1: 11, i2: 10
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# 240/240 [==============================] - 12s 51ms/step - loss: 2.3015 - accuracy: 0.1140 - val_loss: 2.3034 - val_accuracy: 0.1060
# Epoch 12/101
# 240/240 [==============================] - 3s 11ms/step - loss: 2.3016 - accuracy: 0.1140 - val_loss: 2.3025 - val_accuracy: 0.1060
# Epoch 13/101
# 240/240 [==============================] - 1s 4ms/step - loss: 2.3016 - accuracy: 0.1138 - val_loss: 2.3023 - val_accuracy: 0.1060
# Epoch 14/101
# 240/240 [==============================] - 1s 5ms/step - loss: 2.3016 - accuracy: 0.1140 - val_loss: 2.3022 - val_accuracy: 0.1060
# Epoch 15/101
# 240/240 [==============================] - 1s 5ms/step - loss: 2.3016 - accuracy: 0.1140 - val_loss: 2.3035 - val_accuracy: 0.1060
# Epoch 16/101
# 240/240 [==============================] - 1s 5ms/step - loss: 2.3017 - accuracy: 0.1135 - val_loss: 2.3030 - val_accuracy: 0.1060
# Epoch 17/101
# 240/240 [==============================] - 1s 5ms/step - loss: 2.3015 - accuracy: 0.1140 - val_loss: 2.3024 - val_accuracy: 0.1060
# Epoch 18/101
# 240/240 [==============================] - 1s 5ms/step - loss: 2.3017 - accuracy: 0.1137 - val_loss: 2.3024 - val_accuracy: 0.1060
# Epoch 19/101
# 240/240 [==============================] - 1s 5ms/step - loss: 2.3016 - accuracy: 0.1137 - val_loss: 2.3021 - val_accuracy: 0.1060
# Epoch 20/101
# 240/240 [==============================] - 1s 5ms/step - loss: 2.3016 - accuracy: 0.1132 - val_loss: 2.3026 - val_accuracy: 0.1060
# Epoch 21/101
# 235/240 [============================>.] - ETA: 0s - loss: 2.3017 - accuracy: 0.1140epoch: 20, layer-1, i1: 1, i2: 0
# epoch: 20, layer-2, i1: 3, i2: 2
# epoch: 20, layer-3, i1: 5, i2: 4
# epoch: 20, layer-4, i1: 7, i2: 6
# epoch: 20, layer-5, i1: 9, i2: 8
# epoch: 20, layer-6, i1: 11, i2: 10
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# 240/240 [==============================] - 11s 45ms/step - loss: 2.3017 - accuracy: 0.1140 - val_loss: 2.3025 - val_accuracy: 0.1060
# Epoch 22/101
# 240/240 [==============================] - 1s 6ms/step - loss: 2.3016 - accuracy: 0.1138 - val_loss: 2.3022 - val_accuracy: 0.1060
# Epoch 23/101
# 240/240 [==============================] - 1s 6ms/step - loss: 2.3016 - accuracy: 0.1140 - val_loss: 2.3032 - val_accuracy: 0.1060
# Epoch 24/101
# 240/240 [==============================] - 1s 5ms/step - loss: 2.3015 - accuracy: 0.1132 - val_loss: 2.3032 - val_accuracy: 0.1060
# Epoch 25/101
# 240/240 [==============================] - 1s 5ms/step - loss: 2.3015 - accuracy: 0.1135 - val_loss: 2.3032 - val_accuracy: 0.1060
# Epoch 26/101
# 240/240 [==============================] - 1s 6ms/step - loss: 2.3016 - accuracy: 0.1140 - val_loss: 2.3031 - val_accuracy: 0.1060
# Epoch 27/101
# 240/240 [==============================] - 1s 6ms/step - loss: 2.3016 - accuracy: 0.1146 - val_loss: 2.3019 - val_accuracy: 0.1081
# Epoch 28/101
# 240/240 [==============================] - 1s 5ms/step - loss: 2.3016 - accuracy: 0.1135 - val_loss: 2.3028 - val_accuracy: 0.1060
# Epoch 29/101
# 240/240 [==============================] - 1s 6ms/step - loss: 2.3016 - accuracy: 0.1132 - val_loss: 2.3025 - val_accuracy: 0.1060
# Epoch 30/101
# 240/240 [==============================] - 1s 6ms/step - loss: 2.3015 - accuracy: 0.1133 - val_loss: 2.3028 - val_accuracy: 0.1060
# Epoch 31/101
# 235/240 [============================>.] - ETA: 0s - loss: 2.3014 - accuracy: 0.1138epoch: 30, layer-1, i1: 1, i2: 0
# epoch: 30, layer-2, i1: 3, i2: 2
# epoch: 30, layer-3, i1: 5, i2: 4
# epoch: 30, layer-4, i1: 7, i2: 6
# epoch: 30, layer-5, i1: 9, i2: 8
# epoch: 30, layer-6, i1: 11, i2: 10
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# 240/240 [==============================] - 9s 37ms/step - loss: 2.3014 - accuracy: 0.1140 - val_loss: 2.3034 - val_accuracy: 0.1035
# Epoch 32/101
# 240/240 [==============================] - 1s 5ms/step - loss: 2.3018 - accuracy: 0.1130 - val_loss: 2.3023 - val_accuracy: 0.1060
# Epoch 33/101
# 240/240 [==============================] - 1s 4ms/step - loss: 2.3014 - accuracy: 0.1139 - val_loss: 2.3042 - val_accuracy: 0.1060
# Epoch 34/101
# 240/240 [==============================] - 1s 5ms/step - loss: 2.3017 - accuracy: 0.1140 - val_loss: 2.3031 - val_accuracy: 0.1060
# Epoch 35/101
# 240/240 [==============================] - 1s 5ms/step - loss: 2.3015 - accuracy: 0.1140 - val_loss: 2.3028 - val_accuracy: 0.1060
# Epoch 36/101
# 240/240 [==============================] - 1s 4ms/step - loss: 2.3015 - accuracy: 0.1131 - val_loss: 2.3029 - val_accuracy: 0.1060
# Epoch 37/101
# 240/240 [==============================] - 1s 6ms/step - loss: 2.3015 - accuracy: 0.1134 - val_loss: 2.3022 - val_accuracy: 0.1060
# Epoch 38/101
# 240/240 [==============================] - 1s 5ms/step - loss: 2.3016 - accuracy: 0.1136 - val_loss: 2.3019 - val_accuracy: 0.1060
# Epoch 39/101
# 240/240 [==============================] - 1s 5ms/step - loss: 2.3016 - accuracy: 0.1138 - val_loss: 2.3023 - val_accuracy: 0.1060
# Epoch 40/101
# 240/240 [==============================] - 1s 5ms/step - loss: 2.3016 - accuracy: 0.1140 - val_loss: 2.3021 - val_accuracy: 0.1060
# Epoch 41/101
# 236/240 [============================>.] - ETA: 0s - loss: 2.3017 - accuracy: 0.1133epoch: 40, layer-1, i1: 1, i2: 0
# epoch: 40, layer-2, i1: 3, i2: 2
# epoch: 40, layer-3, i1: 5, i2: 4
# epoch: 40, layer-4, i1: 7, i2: 6
# epoch: 40, layer-5, i1: 9, i2: 8
# epoch: 40, layer-6, i1: 11, i2: 10
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# 240/240 [==============================] - 9s 38ms/step - loss: 2.3017 - accuracy: 0.1135 - val_loss: 2.3029 - val_accuracy: 0.1060
# Epoch 42/101
# 240/240 [==============================] - 1s 5ms/step - loss: 2.3016 - accuracy: 0.1140 - val_loss: 2.3025 - val_accuracy: 0.1060
# Epoch 43/101
# 240/240 [==============================] - 1s 5ms/step - loss: 2.3017 - accuracy: 0.1136 - val_loss: 2.3025 - val_accuracy: 0.1060
# Epoch 44/101
# 240/240 [==============================] - 1s 5ms/step - loss: 2.3016 - accuracy: 0.1140 - val_loss: 2.3022 - val_accuracy: 0.1060
# Epoch 45/101
# 240/240 [==============================] - 1s 6ms/step - loss: 2.3015 - accuracy: 0.1131 - val_loss: 2.3025 - val_accuracy: 0.1060
# Epoch 46/101
# 240/240 [==============================] - 1s 6ms/step - loss: 2.3016 - accuracy: 0.1140 - val_loss: 2.3021 - val_accuracy: 0.1060
# Epoch 47/101
# 240/240 [==============================] - 1s 6ms/step - loss: 2.3015 - accuracy: 0.1138 - val_loss: 2.3030 - val_accuracy: 0.1060
# Epoch 48/101
# 240/240 [==============================] - 1s 5ms/step - loss: 2.3016 - accuracy: 0.1137 - val_loss: 2.3026 - val_accuracy: 0.1060
# Epoch 49/101
# 240/240 [==============================] - 2s 7ms/step - loss: 2.3015 - accuracy: 0.1135 - val_loss: 2.3029 - val_accuracy: 0.1060
# Epoch 50/101
# 240/240 [==============================] - 2s 7ms/step - loss: 2.3015 - accuracy: 0.1136 - val_loss: 2.3027 - val_accuracy: 0.1060
# Epoch 51/101
# 226/240 [===========================>..] - ETA: 0s - loss: 2.3016 - accuracy: 0.1138epoch: 50, layer-1, i1: 1, i2: 0
# epoch: 50, layer-2, i1: 3, i2: 2
# epoch: 50, layer-3, i1: 5, i2: 4
# epoch: 50, layer-4, i1: 7, i2: 6
# epoch: 50, layer-5, i1: 9, i2: 8
# epoch: 50, layer-6, i1: 11, i2: 10
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# 240/240 [==============================] - 10s 42ms/step - loss: 2.3016 - accuracy: 0.1138 - val_loss: 2.3023 - val_accuracy: 0.1060
# Epoch 52/101
# 240/240 [==============================] - 1s 5ms/step - loss: 2.3016 - accuracy: 0.1137 - val_loss: 2.3019 - val_accuracy: 0.1060
# Epoch 53/101
# 240/240 [==============================] - 1s 5ms/step - loss: 2.3015 - accuracy: 0.1138 - val_loss: 2.3026 - val_accuracy: 0.1060
# Epoch 54/101
# 240/240 [==============================] - 1s 6ms/step - loss: 2.3016 - accuracy: 0.1140 - val_loss: 2.3028 - val_accuracy: 0.1060
# Epoch 55/101
# 240/240 [==============================] - 2s 7ms/step - loss: 2.3016 - accuracy: 0.1137 - val_loss: 2.3022 - val_accuracy: 0.1060
# Epoch 56/101
# 240/240 [==============================] - 1s 6ms/step - loss: 2.3017 - accuracy: 0.1136 - val_loss: 2.3031 - val_accuracy: 0.1060
# Epoch 57/101
# 240/240 [==============================] - 2s 6ms/step - loss: 2.3015 - accuracy: 0.1140 - val_loss: 2.3024 - val_accuracy: 0.1060
# Epoch 58/101
# 240/240 [==============================] - 1s 5ms/step - loss: 2.3015 - accuracy: 0.1133 - val_loss: 2.3025 - val_accuracy: 0.1060
# Epoch 59/101
# 240/240 [==============================] - 1s 6ms/step - loss: 2.3015 - accuracy: 0.1136 - val_loss: 2.3027 - val_accuracy: 0.1060
# Epoch 60/101
# 240/240 [==============================] - 1s 4ms/step - loss: 2.3016 - accuracy: 0.1140 - val_loss: 2.3019 - val_accuracy: 0.1060
# Epoch 61/101
# 232/240 [============================>.] - ETA: 0s - loss: 2.3018 - accuracy: 0.1134epoch: 60, layer-1, i1: 1, i2: 0
# epoch: 60, layer-2, i1: 3, i2: 2
# epoch: 60, layer-3, i1: 5, i2: 4
# epoch: 60, layer-4, i1: 7, i2: 6
# epoch: 60, layer-5, i1: 9, i2: 8
# epoch: 60, layer-6, i1: 11, i2: 10
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# 240/240 [==============================] - 9s 36ms/step - loss: 2.3016 - accuracy: 0.1140 - val_loss: 2.3024 - val_accuracy: 0.1060
# Epoch 62/101
# 240/240 [==============================] - 1s 5ms/step - loss: 2.3017 - accuracy: 0.1138 - val_loss: 2.3020 - val_accuracy: 0.1060
# Epoch 63/101
# 240/240 [==============================] - 1s 5ms/step - loss: 2.3015 - accuracy: 0.1140 - val_loss: 2.3025 - val_accuracy: 0.1060
# Epoch 64/101
# 240/240 [==============================] - 1s 6ms/step - loss: 2.3015 - accuracy: 0.1134 - val_loss: 2.3034 - val_accuracy: 0.1060
# Epoch 65/101
# 240/240 [==============================] - 1s 5ms/step - loss: 2.3015 - accuracy: 0.1132 - val_loss: 2.3036 - val_accuracy: 0.1060
# Epoch 66/101
# 240/240 [==============================] - 1s 5ms/step - loss: 2.3015 - accuracy: 0.1136 - val_loss: 2.3029 - val_accuracy: 0.1060
# Epoch 67/101
# 240/240 [==============================] - 1s 6ms/step - loss: 2.3016 - accuracy: 0.1137 - val_loss: 2.3022 - val_accuracy: 0.1060
# Epoch 68/101
# 240/240 [==============================] - 1s 6ms/step - loss: 2.3015 - accuracy: 0.1135 - val_loss: 2.3026 - val_accuracy: 0.1060
# Epoch 69/101
# 240/240 [==============================] - 1s 6ms/step - loss: 2.3016 - accuracy: 0.1137 - val_loss: 2.3020 - val_accuracy: 0.1060
# Epoch 70/101
# 240/240 [==============================] - 1s 6ms/step - loss: 2.3016 - accuracy: 0.1140 - val_loss: 2.3023 - val_accuracy: 0.1060
# Epoch 71/101
# 232/240 [============================>.] - ETA: 0s - loss: 2.3016 - accuracy: 0.1133epoch: 70, layer-1, i1: 1, i2: 0
# epoch: 70, layer-2, i1: 3, i2: 2
# epoch: 70, layer-3, i1: 5, i2: 4
# epoch: 70, layer-4, i1: 7, i2: 6
# epoch: 70, layer-5, i1: 9, i2: 8
# epoch: 70, layer-6, i1: 11, i2: 10
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# 240/240 [==============================] - 11s 46ms/step - loss: 2.3016 - accuracy: 0.1136 - val_loss: 2.3026 - val_accuracy: 0.1060
# Epoch 72/101
# 240/240 [==============================] - 1s 5ms/step - loss: 2.3015 - accuracy: 0.1135 - val_loss: 2.3030 - val_accuracy: 0.1060
# Epoch 73/101
# 240/240 [==============================] - 1s 5ms/step - loss: 2.3016 - accuracy: 0.1140 - val_loss: 2.3024 - val_accuracy: 0.1060
# Epoch 74/101
# 240/240 [==============================] - 1s 4ms/step - loss: 2.3016 - accuracy: 0.1138 - val_loss: 2.3020 - val_accuracy: 0.1060
# Epoch 75/101
# 240/240 [==============================] - 1s 5ms/step - loss: 2.3016 - accuracy: 0.1138 - val_loss: 2.3029 - val_accuracy: 0.1060
# Epoch 76/101
# 240/240 [==============================] - 1s 5ms/step - loss: 2.3016 - accuracy: 0.1140 - val_loss: 2.3025 - val_accuracy: 0.1060
# Epoch 77/101
# 240/240 [==============================] - 1s 5ms/step - loss: 2.3016 - accuracy: 0.1140 - val_loss: 2.3023 - val_accuracy: 0.1060
# Epoch 78/101
# 240/240 [==============================] - 1s 5ms/step - loss: 2.3015 - accuracy: 0.1135 - val_loss: 2.3024 - val_accuracy: 0.1060
# Epoch 79/101
# 240/240 [==============================] - 1s 5ms/step - loss: 2.3015 - accuracy: 0.1140 - val_loss: 2.3028 - val_accuracy: 0.1060
# Epoch 80/101
# 240/240 [==============================] - 1s 5ms/step - loss: 2.3016 - accuracy: 0.1140 - val_loss: 2.3028 - val_accuracy: 0.1060
# Epoch 81/101
# 234/240 [============================>.] - ETA: 0s - loss: 2.3015 - accuracy: 0.1141epoch: 80, layer-1, i1: 1, i2: 0
# epoch: 80, layer-2, i1: 3, i2: 2
# epoch: 80, layer-3, i1: 5, i2: 4
# epoch: 80, layer-4, i1: 7, i2: 6
# epoch: 80, layer-5, i1: 9, i2: 8
# epoch: 80, layer-6, i1: 11, i2: 10
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# 240/240 [==============================] - 10s 44ms/step - loss: 2.3015 - accuracy: 0.1139 - val_loss: 2.3018 - val_accuracy: 0.1060
# Epoch 82/101
# 240/240 [==============================] - 1s 4ms/step - loss: 2.3016 - accuracy: 0.1138 - val_loss: 2.3021 - val_accuracy: 0.1060
# Epoch 83/101
# 240/240 [==============================] - 1s 6ms/step - loss: 2.3016 - accuracy: 0.1137 - val_loss: 2.3020 - val_accuracy: 0.1060
# Epoch 84/101
# 240/240 [==============================] - 2s 6ms/step - loss: 2.3015 - accuracy: 0.1139 - val_loss: 2.3023 - val_accuracy: 0.1060
# Epoch 85/101
# 240/240 [==============================] - 1s 6ms/step - loss: 2.3017 - accuracy: 0.1134 - val_loss: 2.3021 - val_accuracy: 0.1060
# Epoch 86/101
# 240/240 [==============================] - 1s 6ms/step - loss: 2.3015 - accuracy: 0.1137 - val_loss: 2.3020 - val_accuracy: 0.1060
# Epoch 87/101
# 240/240 [==============================] - 1s 5ms/step - loss: 2.3016 - accuracy: 0.1134 - val_loss: 2.3027 - val_accuracy: 0.1060
# Epoch 88/101
# 240/240 [==============================] - 1s 5ms/step - loss: 2.3015 - accuracy: 0.1138 - val_loss: 2.3021 - val_accuracy: 0.1060
# Epoch 89/101
# 240/240 [==============================] - 1s 6ms/step - loss: 2.3016 - accuracy: 0.1137 - val_loss: 2.3026 - val_accuracy: 0.1060
# Epoch 90/101
# 240/240 [==============================] - 1s 6ms/step - loss: 2.3015 - accuracy: 0.1135 - val_loss: 2.3024 - val_accuracy: 0.1060
# Epoch 91/101
# 237/240 [============================>.] - ETA: 0s - loss: 2.3014 - accuracy: 0.1140epoch: 90, layer-1, i1: 1, i2: 0
# epoch: 90, layer-2, i1: 3, i2: 2
# epoch: 90, layer-3, i1: 5, i2: 4
# epoch: 90, layer-4, i1: 7, i2: 6
# epoch: 90, layer-5, i1: 9, i2: 8
# epoch: 90, layer-6, i1: 11, i2: 10
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# 240/240 [==============================] - 9s 37ms/step - loss: 2.3014 - accuracy: 0.1139 - val_loss: 2.3025 - val_accuracy: 0.1060
# Epoch 92/101
# 240/240 [==============================] - 1s 5ms/step - loss: 2.3015 - accuracy: 0.1136 - val_loss: 2.3022 - val_accuracy: 0.1060
# Epoch 93/101
# 240/240 [==============================] - 1s 6ms/step - loss: 2.3015 - accuracy: 0.1135 - val_loss: 2.3027 - val_accuracy: 0.1060
# Epoch 94/101
# 240/240 [==============================] - 2s 6ms/step - loss: 2.3016 - accuracy: 0.1140 - val_loss: 2.3025 - val_accuracy: 0.1060
# Epoch 95/101
# 240/240 [==============================] - 1s 5ms/step - loss: 2.3016 - accuracy: 0.1140 - val_loss: 2.3025 - val_accuracy: 0.1060
# Epoch 96/101
# 240/240 [==============================] - 1s 6ms/step - loss: 2.3016 - accuracy: 0.1140 - val_loss: 2.3023 - val_accuracy: 0.1060
# Epoch 97/101
# 240/240 [==============================] - 1s 6ms/step - loss: 2.3016 - accuracy: 0.1140 - val_loss: 2.3032 - val_accuracy: 0.1060
# Epoch 98/101
# 240/240 [==============================] - 1s 6ms/step - loss: 2.3017 - accuracy: 0.1135 - val_loss: 2.3018 - val_accuracy: 0.1060
# Epoch 99/101
# 240/240 [==============================] - 1s 5ms/step - loss: 2.3016 - accuracy: 0.1138 - val_loss: 2.3023 - val_accuracy: 0.1060
# Epoch 100/101
# 240/240 [==============================] - 1s 6ms/step - loss: 2.3016 - accuracy: 0.1140 - val_loss: 2.3022 - val_accuracy: 0.1060
# Epoch 101/101
# 225/240 [===========================>..] - ETA: 0s - loss: 2.3017 - accuracy: 0.1140epoch: 100, layer-1, i1: 1, i2: 0
# epoch: 100, layer-2, i1: 3, i2: 2
# epoch: 100, layer-3, i1: 5, i2: 4
# epoch: 100, layer-4, i1: 7, i2: 6
# epoch: 100, layer-5, i1: 9, i2: 8
# epoch: 100, layer-6, i1: 11, i2: 10
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# type_i: <class 'int'>, type_f: <class 'tensorflow.python.framework.ops.EagerTensor'>
# 240/240 [==============================] - 9s 36ms/step - loss: 2.3016 - accuracy: 0.1140 - val_loss: 2.3021 - val_accuracy: 0.1060

# %%
# %tensorboard --logdir ./logs/3201
# Out:
# Launching TensorBoard...
#       <iframe id="tensorboard-frame-c9b6be61e2f42d7f" width="100%" height="800" frameborder="0">
#       </iframe>
#       <script>
#         (function() {
#           const frame = document.getElementById("tensorboard-frame-c9b6be61e2f42d7f");
#           const url = new URL("/", window.location);
#           const port = 6006;
#           if (port) {
#             url.port = port;
#           }
#           frame.src = url;
#         })();
#       </script>
